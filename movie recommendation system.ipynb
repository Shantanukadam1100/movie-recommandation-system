# %%
import pandas as pd 
import numpy as np 

movies = pd.read_csv("tmdb_5000_movies.csv")
credits = pd.read_csv("tmdb_5000_credits.csv")

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies=movies.merge(credits,on="title")

# %%
movies.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3096
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# movie_id                   0
# cast                       0
# crew                       0
# dtype: int64

# %%
movies.head()
data=movies[["title","overview"]]

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'movie_id', 'cast', 'crew'],
#       dtype='object')

# %%
no_required = ["budget","homepage","movie_id","original_language","original_title",
              "popularity","production_companies","production_countries","release_date","revenue","spoken_languages","tagline",
               "vote_average","vote_count"]

# %%
movies["original_language"].value_counts()
# Out:
# en    4510
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# ko      12
# cn      12
# ru      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# ta       2
# cs       2
# ro       2
# id       2
# ar       2
# vi       1
# sl       1
# ps       1
# no       1
# ky       1
# hu       1
# pl       1
# af       1
# nb       1
# tr       1
# is       1
# xx       1
# te       1
# el       1
# Name: original_language, dtype: int64

# %%
len(no_required)
# Out:
# 14

# %%
movies=movies.drop(columns=no_required)

# %%
movies.shape
# Out:
# (4809, 9)

# %%
movies.isnull().sum()
# Out:
# genres      0
# id          0
# keywords    0
# overview    3
# runtime     2
# status      0
# title       0
# cast        0
# crew        0
# dtype: int64

# %%
movies.drop(columns=["runtime","status"],inplace=True)

# %%
movies.columns
# Out:
# Index(['genres', 'id', 'keywords', 'overview', 'title', 'cast', 'crew'], dtype='object')

# %%
movies.isnull().sum()
# Out:
# genres      0
# id          0
# keywords    0
# overview    3
# title       0
# cast        0
# crew        0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
movies.isnull().sum()
# Out:
# genres      0
# id          0
# keywords    0
# overview    0
# title       0
# cast        0
# crew        0
# dtype: int64

# %%
s=movies.genres[0]

# %%
import ast
s=ast.literal_eval(s)

# %%
s[0]["name"]
# Out:
# 'Action'

# %%
def helper(obj):
    l=[]
    for i in ast.literal_eval(obj):
        l.append(i["name"])
    return l

# %%
movies["genres"]=movies["genres"].apply(helper)

# %%
movies
# Out:
#                                              genres      id  \
# 0     [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                      [Adventure, Fantasy, Action]     285
# 2                        [Action, Adventure, Crime]  206647
# 3                  [Action, Crime, Drama, Thriller]   49026
# 4              [Action, Adventure, Science Fiction]   49529
# ...                                             ...     ...
# 4804                      [Action, Crime, Thriller]    9367
# 4805                              [Comedy, Romance]   72766
# 4806             [Comedy, Drama, Romance, TV Movie]  231617
# 4807                                             []  126186
# 4808                                  [Documentary]   25975
#
#                                                keywords  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...
# ...

# %%
movies.keywords[0]
# Out:
# '[{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name": "mind and soul"}, {"id": 209714, "name": "3d"}]'

# %%
movies["keywords"]=movies["keywords"].apply(helper)

# %%
s=movies.cast[0]

# %%
s=ast.literal_eval(s)

# %%
lst=[]
count=0
for i in s:
    if count!=5:
        lst.append(i["name"])
        count=count+1
    else:
        break

# %%
lst
# Out:
# ['Sam Worthington',
#  'Zoe Saldana',
#  'Sigourney Weaver',
#  'Stephen Lang',
#  'Michelle Rodriguez']

# %%
def helper2(x):
    lst=[]
    count=0
    for i in ast.literal_eval(x):
        if count!=5:
            lst.append(i["name"])
            count=count+1
        else:
            break
    return lst

# %%
movies["cast"]=movies["cast"].apply(helper2)

# %%
s=movies["crew"][0]

# %%
s=ast.literal_eval(s)

# %%
s
# Out:
# [{'credit_id': '52fe48009251416c750aca23',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 1721,
#   'job': 'Editor',
#   'name': 'Stephen E. Rivkin'},
#  {'credit_id': '539c47ecc3a36810e3001f87',
#   'department': 'Art',
#   'gender': 2,
#   'id': 496,
#   'job': 'Production Design',
#   'name': 'Rick Carter'},
#  {'credit_id': '54491c89c3a3680fb4001cf7',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 900,
#   'job': 'Sound Designer',
#   'name': 'Christopher Boyes'},
#  {'credit_id': '54491cb70e0a267480001bd0',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 900,
#   'job': 'Supervising Sound Editor',
#   'name': 'Christopher Boyes'},
#  {'credit_id': '539c4a4cc3a36810c9002101',
#   'department': 'Production',
#   'gender': 1,
#   'id': 1262,
#   'job': 'Casting',
#   'name': 'Mali Finn'},
#  {'credit_id': '5544ee3b925141499f0008fc',
#   'department': 'Sound',
#   'gender': 2,
#   'id': 1729,
#   'job': 'Original Music Composer',
#   'name': 'James Horner'},
# ...

# %%
def helper3(obj):
    directors=[]
    for i in ast.literal_eval(obj):
        if i["job"]=="Director":
            directors.append(i["name"])
        else:
            pass
    return directors

# %%
movies["crew"]=movies["crew"].apply(helper3)

# %%
movies.head(1)
# Out:
#                                           genres     id  \
# 0  [Action, Adventure, Fantasy, Science Fiction]  19995
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
#
#                                             overview   title  \
# 0  In the 22nd century, a paraplegic Marine is di...  Avatar
#
#                                                 cast             crew
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...  [James Cameron]

# %%
s=movies.overview[0]

# %%
s
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %%
movies["overview"]=movies["overview"].apply(lambda x:x.split())

# %%
movies_data=movies.copy()

# %%
movies.head()
# Out:
#                                           genres      id  \
# 0  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                   [Adventure, Fantasy, Action]     285
# 2                     [Action, Adventure, Crime]  206647
# 3               [Action, Crime, Drama, Thriller]   49026
# 4           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# ...

# %%
movies["genres"]=movies["genres"].apply(lambda x: [i.replace(" ","") for i in x])

# %%
movies["keywords"]=movies["keywords"].apply(lambda x: [i.replace(" ","") for i in x])
movies["cast"]=movies["cast"].apply(lambda x: [i.replace(" ","") for i in x])
movies["crew"]=movies["crew"].apply(lambda x: [i.replace(" ","") for i in x])

# %%
movies
# Out:
#                                             genres      id  \
# 0     [Action, Adventure, Fantasy, ScienceFiction]   19995
# 1                     [Adventure, Fantasy, Action]     285
# 2                       [Action, Adventure, Crime]  206647
# 3                 [Action, Crime, Drama, Thriller]   49026
# 4              [Action, Adventure, ScienceFiction]   49529
# ...                                            ...     ...
# 4804                     [Action, Crime, Thriller]    9367
# 4805                             [Comedy, Romance]   72766
# 4806             [Comedy, Drama, Romance, TVMovie]  231617
# 4807                                            []  126186
# 4808                                 [Documentary]   25975
#
#                                                keywords  \
# 0     [cultureclash, future, spacewar, spacecolony, ...
# 1     [ocean, drugabuse, exoticisland, eastindiatrad...
# 2     [spy, basedonnovel, secretagent, sequel, mi6, ...
# ...

# %%
movies["tags"] = movies["overview"]+movies["genres"]+movies["keywords"]+movies["cast"]+movies["crew"]

# %%
movies
# Out:
#                                             genres      id  \
# 0     [Action, Adventure, Fantasy, ScienceFiction]   19995
# 1                     [Adventure, Fantasy, Action]     285
# 2                       [Action, Adventure, Crime]  206647
# 3                 [Action, Crime, Drama, Thriller]   49026
# 4              [Action, Adventure, ScienceFiction]   49529
# ...                                            ...     ...
# 4804                     [Action, Crime, Thriller]    9367
# 4805                             [Comedy, Romance]   72766
# 4806             [Comedy, Drama, Romance, TVMovie]  231617
# 4807                                            []  126186
# 4808                                 [Documentary]   25975
#
#                                                keywords  \
# 0     [cultureclash, future, spacewar, spacecolony, ...
# 1     [ocean, drugabuse, exoticisland, eastindiatrad...
# 2     [spy, basedonnovel, secretagent, sequel, mi6, ...
# ...

# %%
df=movies[["id","title","tags"]]

# %%
df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                    tags
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# 3     [Following, the, death, of, District, Attorney...
# ...

# %%
df["tags"]=df["tags"].apply(lambda x:" ".join(x))
# Out:
# C:\Users\kadam\AppData\Local\Temp\ipykernel_22760\1953715827.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tags"]=df["tags"].apply(lambda x:" ".join(x))

# %%
df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                    tags
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# ...

# %%
df["tags"]=df["tags"].apply(lambda x:x.lower())
# Out:
# C:\Users\kadam\AppData\Local\Temp\ipykernel_22760\2543080859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tags"]=df["tags"].apply(lambda x:x.lower())

# %%
df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                    tags
# 0     in the 22nd century, a paraplegic marine is di...
# 1     captain barbossa, long believed to be dead, ha...
# 2     a cryptic message from bond’s past sends him o...
# 3     following the death of district attorney harve...
# ...

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y =[]
    
    for i in text.split():
        y.append(ps.stem(i))
        
    return " ".join(y)

# %%
df["tags"]=df["tags"].apply(stem)
# Out:
# C:\Users\kadam\AppData\Local\Temp\ipykernel_22760\507833537.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tags"]=df["tags"].apply(stem)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words="english")

# %%
vectors = cv.fit_transform(df["tags"]).toarray()

# %%
cv.fit_transform(df["tags"]).toarray().shape
# Out:
# (4806, 5000)

# %%
cv.get_feature_names()
# Out:
# D:\movies\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['000',
#  '007',
#  '10',
#  '100',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16',
#  '17',
#  '17th',
#  '18',
#  '18th',
#  '18thcenturi',
#  '19',
#  '1910',
#  '1920',
#  '1930',
#  '1940',
#  '1944',
#  '1950',
#  '1950s',
#  '1960',
#  '1960s',
#  '1970',
#  '1970s',
#  '1971',
#  '1974',
#  '1976',
#  '1980',
#  '1985',
#  '1990',
#  '1999',
#  '19th',
#  '19thcenturi',
#  '20',
#  '200',
#  '2003',
#  '2009',
#  '20th',
#  '21st',
#  '23',
#  '24',
#  '25',
#  '30',
#  '300',
#  '3d',
#  '40',
#  '50',
#  '500',
#  '60',
#  '70',
#  '80',
#  'aaron',
#  'aaroneckhart',
#  'aarontaylor',
#  'abandon',
#  'abduct',
#  'abigailbreslin',
#  'abil',
#  'abl',
#  'aboard',
#  'abov',
#  'abus',
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity(vectors)
# Out:
# array([[1.        , 0.08108108, 0.08718573, ..., 0.04604093, 0.        ,
#         0.        ],
#        [0.08108108, 1.        , 0.05812382, ..., 0.02302046, 0.        ,
#         0.02507061],
#        [0.08718573, 0.05812382, 1.        , ..., 0.02475369, 0.        ,
#         0.        ],
#        ...,
#        [0.04604093, 0.02302046, 0.02475369, ..., 1.        , 0.040008  ,
#         0.04270814],
#        [0.        , 0.        , 0.        , ..., 0.040008  , 1.        ,
#         0.08714204],
#        [0.        , 0.02507061, 0.        , ..., 0.04270814, 0.08714204,
#         1.        ]])

# %%
cosine_similarity(vectors).shape
# Out:
# (4806, 4806)

# %%
similarity=cosine_similarity(vectors)
similarity[1].min()
# Out:
# 0.0

# %%
list(enumerate(similarity[0]))
# Out:
# [(0, 1.0),
#  (1, 0.08108108108108109),
#  (2, 0.08718572905786445),
#  (3, 0.07352146220938077),
#  (4, 0.1898315991504998),
#  (5, 0.1098436937909367),
#  (6, 0.04078236951430929),
#  (7, 0.14543584966911588),
#  (8, 0.059053859535749265),
#  (9, 0.09592022754223367),
#  (10, 0.10146925788636821),
#  (11, 0.09491579957524991),
#  (12, 0.0885807893036239),
#  (13, 0.04433510985214727),
#  (14, 0.12683657235796025),
#  (15, 0.06906138832741962),
#  (16, 0.07798128673650545),
#  (17, 0.13955413899505748),
#  (18, 0.09687303228651607),
#  (19, 0.08489527199560176),
#  (20, 0.058352204610730346),
#  (21, 0.106676149412533),
#  (22, 0.07009996372327816),
#  (23, 0.08718572905786445),
#  (24, 0.05479966243511909),
#  (25, 0.03446739311292904),
#  (26, 0.15404884978892902),
#  (27, 0.19101436199010396),
#  (28, 0.11115400287534567),
#  (29, 0.06590621627456203),
#  (30, 0.06711560552140243),
#  (31, 0.1553424415003),
#  (32, 0.08489527199560176),
#  (33, 0.0949157995752499),
#  (34, 0.0),
# ...

# %%
sorted(list(enumerate(similarity[0])),reverse=True,key=lambda x:x[1])[1:6]
# Out:
# [(1216, 0.2926585541394632),
#  (507, 0.26130213378560535),
#  (3730, 0.25732511773283273),
#  (582, 0.2484013136974297),
#  (539, 0.2465984809580359)]

# %%
def recommend(movie):
    movie_index=df[df["title"]==movie].index[0]
    distances=similarity[movie_index]
    movies_list=sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]
    l=[]
    for i in movies_list:
        #print(i[0])
        l.append(i[0])
        
    for i in l:
        print("Recommanded movies are ", df.iloc[i].title)
        print("Overview : ", data.iloc[i].overview)
        print("---------------***-----------------------***------------------------***-----------------------")

# %%
import pickle

# %%
#pickle.dump(df,open("movies.pkl","wb"))

# %%
df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                    tags
# 0     in the 22nd century, a parapleg marin is dispa...
# 1     captain barbossa, long believ to be dead, ha c...
# 2     a cryptic messag from bond’ past send him on a...
# 3     follow the death of district attorney harvey d...
# ...

# %%
movies
# Out:
#                                             genres      id  \
# 0     [Action, Adventure, Fantasy, ScienceFiction]   19995
# 1                     [Adventure, Fantasy, Action]     285
# 2                       [Action, Adventure, Crime]  206647
# 3                 [Action, Crime, Drama, Thriller]   49026
# 4              [Action, Adventure, ScienceFiction]   49529
# ...                                            ...     ...
# 4804                     [Action, Crime, Thriller]    9367
# 4805                             [Comedy, Romance]   72766
# 4806             [Comedy, Drama, Romance, TVMovie]  231617
# 4807                                            []  126186
# 4808                                 [Documentary]   25975
#
#                                                keywords  \
# 0     [cultureclash, future, spacewar, spacecolony, ...
# 1     [ocean, drugabuse, exoticisland, eastindiatrad...
# 2     [spy, basedonnovel, secretagent, sequel, mi6, ...
# ...

# %%
df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                    tags
# 0     in the 22nd century, a parapleg marin is dispa...
# 1     captain barbossa, long believ to be dead, ha c...
# 2     a cryptic messag from bond’ past send him on a...
# 3     follow the death of district attorney harvey d...
# ...

# %%
#pickle.dump(similarity,open("similarity.pkl","wb"))

# %%
similarity
# Out:
# array([[1.        , 0.08108108, 0.08718573, ..., 0.04604093, 0.        ,
#         0.        ],
#        [0.08108108, 1.        , 0.05812382, ..., 0.02302046, 0.        ,
#         0.02507061],
#        [0.08718573, 0.05812382, 1.        , ..., 0.02475369, 0.        ,
#         0.        ],
#        ...,
#        [0.04604093, 0.02302046, 0.02475369, ..., 1.        , 0.040008  ,
#         0.04270814],
#        [0.        , 0.        , 0.        , ..., 0.040008  , 1.        ,
#         0.08714204],
#        [0.        , 0.02507061, 0.        , ..., 0.04270814, 0.08714204,
#         1.        ]])

# %%
pickle.dump(movies_data.to_dict(),open("movies_data.pkl","wb"))
